# %% [markdown]
# # Session 6: Tool Use, Function Calling, and ReAct
#
# ## Session Focus
# Equip agents with tools, structured function calls, and ReAct-style control flow.

# %% [markdown]
# ## Learning Objectives
# - Add tool access to an existing agent
# - Design and invoke function schemas reliably
# - Implement ReAct style reasoning and action loops
# - Explore short-term and persistent memory patterns

# %% [markdown]
# ## Session Topics
# - Agent tools: web search, calculator, APIs, and databases
# - OpenAI function calling concepts
# - ReAct pattern: interleaved reasoning and acting
# - Agent memory: short-term and long-term concepts
# - Intro to multi-agent collaboration patterns

# %% [markdown]
# ## Hands-on Labs
# 1. Extend Session 5 agent with web search and calculator tools
# 2. Implement and log ReAct thought-action-observation cycles
# 3. Experiment with memory persistence across turns

# %%
# Function-calling style schema skeleton
tools = [
    {
        "name": "calculator",
        "description": "Evaluate arithmetic expressions",
        "parameters": {
            "type": "object",
            "properties": {
                "expression": {"type": "string"}
            },
            "required": ["expression"]
        }
    }
]

react_trace = [
    {"thought": "Need account usage summary", "action": "web_search", "observation": "TODO"},
    {"thought": "Need bill estimate", "action": "calculator", "observation": "TODO"}
]

tools, react_trace
